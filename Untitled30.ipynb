# %% [markdown]
# <a href="https://colab.research.google.com/github/anusreeanilanu/mainproject/blob/main/Untitled30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Embedding, Conv1D, LSTM, Dropout
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/train.tsv', sep='\t')
label_counts = df['label'].value_counts()
plt.bar(label_counts.index, label_counts.values)
plt.xlabel('Label')
plt.ylabel('Count')
plt.show()

# %%
from wordcloud import WordCloud
text = ' '.join(df['text'].tolist())
wordcloud = WordCloud(background_color='white').generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text_lengths = df['text'].apply(len)
plt.hist(text_lengths, bins=50)
plt.xlabel('Text Length')
plt.ylabel('Count')
plt.show()

# %%
df["text_length"] = text_lengths
plt.scatter(df['label'], df['text_length'], alpha=0.2)
plt.xlabel('Label')
plt.ylabel('Text Length')
plt.show()

# %%
df.boxplot("text_length", by='label', figsize=(10, 6))
plt.xlabel('Label')
plt.ylabel('Text Length')
plt.show()

# %%
class TextDataset:
    def __init__(self, dataset_file='train.tsv'):
        self.dataset_file = dataset_file
        self.df = pd.read_csv(dataset_file, sep='\t')
        self.tokenizer = None
        self.max_sequence_length = None

    def prepare_data(self, max_sequence_length=100, num_words=10000, test_size=0.2, validation_size=0.2):
        lemmatizer = WordNetLemmatizer()
        self.df['text'] = self.df['text'].apply(lambda x: ' '.join([lemmatizer.lemmatize(w.lower()) for w in word_tokenize(x)]))
        self.tokenizer = Tokenizer(num_words=num_words, lower=True)
        self.tokenizer.fit_on_texts(self.df['text'])
        self.max_sequence_length = max_sequence_length
        sequences = self.tokenizer.texts_to_sequences(self.df['text'])
        sequences = pad_sequences(sequences, maxlen=max_sequence_length, padding='post')

        labels = np.array(self.df['label'])
        indices = np.arange(len(labels))
        np.random.shuffle(indices)
        sequences = sequences[indices]
        labels = labels[indices]
        num_test = int(len(labels) * test_size)
        num_validation = int(len(labels) * validation_size)
        num_train = len(labels) - num_validation - num_test
        self.x_train = sequences[:num_train]
        self.y_train = labels[:num_train]
        self.x_val = sequences[num_train:num_train+num_validation]
        self.y_val = labels[num_train:num_train+num_validation]
        self.x_test = sequences[-num_test:]
        self.y_test = labels[-num_test:]

    def create_model(self, embedding_dim=50, num_filters=64, filter_size=3, dropout_rate=0.5, lstm_units=64):
        model = Sequential()
        model.add(Embedding(input_dim=self.tokenizer.num_words, output_dim=embedding_dim, input_length=self.max_sequence_length))
        model.add(Conv1D(num_filters, filter_size, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(LSTM(lstm_units))
        model.add(Dense(1, activation='sigmoid'))
        model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
        return model

# %%
text_dataset = TextDataset('/content/drive/MyDrive/train.tsv')

# %%
text_dataset.prepare_data()

# %%
model = text_dataset.create_model()

# %%
history = model.fit(text_dataset.x_train, text_dataset.y_train, epochs=100, batch_size=32, validation_data=(text_dataset.x_val, text_dataset.y_val))
# Out:
# Epoch 1/100
# 3765/3765 [==============================] - 95s 22ms/step - loss: 0.0549 - accuracy: 0.9769 - val_loss: 0.0208 - val_accuracy: 0.9938
# Epoch 2/100
# 3765/3765 [==============================] - 36s 10ms/step - loss: 0.0131 - accuracy: 0.9959 - val_loss: 0.0246 - val_accuracy: 0.9942
# Epoch 3/100
# 3765/3765 [==============================] - 37s 10ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.0165 - val_accuracy: 0.9956
# Epoch 4/100
# 3765/3765 [==============================] - 36s 9ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0173 - val_accuracy: 0.9945
# Epoch 5/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.0413 - val_accuracy: 0.9916
# Epoch 6/100
# 3765/3765 [==============================] - 37s 10ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0237 - val_accuracy: 0.9944
# Epoch 7/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0209 - val_accuracy: 0.9950
# Epoch 8/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0163 - val_accuracy: 0.9959
# Epoch 9/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0184 - val_accuracy: 0.9958
# Epoch 10/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 9.1905e-04 - accuracy: 0.9997 - val_loss: 0.0269 - val_accuracy: 0.9952
# Epoch 11/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 8.4489e-04 - accuracy: 0.9998 - val_loss: 0.0219 - val_accuracy: 0.9954
# Epoch 12/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 5.6909e-04 - accuracy: 0.9998 - val_loss: 0.0279 - val_accuracy: 0.9946
# Epoch 13/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 6.8214e-04 - accuracy: 0.9998 - val_loss: 0.0218 - val_accuracy: 0.9950
# Epoch 14/100
# 3765/3765 [==============================] - 36s 9ms/step - loss: 5.1261e-04 - accuracy: 0.9999 - val_loss: 0.0196 - val_accuracy: 0.9955
# Epoch 15/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 3.2154e-04 - accuracy: 0.9999 - val_loss: 0.0151 - val_accuracy: 0.9958
# Epoch 16/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.6332e-04 - accuracy: 0.9999 - val_loss: 0.0250 - val_accuracy: 0.9947
# Epoch 17/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 4.5863e-04 - accuracy: 0.9999 - val_loss: 0.0227 - val_accuracy: 0.9951
# Epoch 18/100
# 3765/3765 [==============================] - 37s 10ms/step - loss: 4.1865e-04 - accuracy: 0.9999 - val_loss: 0.0249 - val_accuracy: 0.9952
# Epoch 19/100
# 3765/3765 [==============================] - 38s 10ms/step - loss: 7.8753e-05 - accuracy: 1.0000 - val_loss: 0.0282 - val_accuracy: 0.9955
# Epoch 20/100
# 3765/3765 [==============================] - 37s 10ms/step - loss: 2.7091e-04 - accuracy: 0.9999 - val_loss: 0.0296 - val_accuracy: 0.9956
# Epoch 21/100
# 3765/3765 [==============================] - 38s 10ms/step - loss: 3.0639e-04 - accuracy: 0.9999 - val_loss: 0.0288 - val_accuracy: 0.9957
# Epoch 22/100
# 3765/3765 [==============================] - 42s 11ms/step - loss: 2.4610e-04 - accuracy: 0.9999 - val_loss: 0.0284 - val_accuracy: 0.9960
# Epoch 23/100
# 3765/3765 [==============================] - 42s 11ms/step - loss: 3.0700e-04 - accuracy: 0.9999 - val_loss: 0.0312 - val_accuracy: 0.9951
# Epoch 24/100
# 3765/3765 [==============================] - 37s 10ms/step - loss: 1.4357e-04 - accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9956
# Epoch 25/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.7923e-04 - accuracy: 0.9999 - val_loss: 0.0228 - val_accuracy: 0.9958
# Epoch 26/100
# 3765/3765 [==============================] - 36s 10ms/step - loss: 1.6692e-04 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9960
# Epoch 27/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 4.7877e-05 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9960
# Epoch 28/100
# 3765/3765 [==============================] - 36s 10ms/step - loss: 1.1251e-04 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9957
# Epoch 29/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 6.1143e-05 - accuracy: 1.0000 - val_loss: 0.0359 - val_accuracy: 0.9951
# Epoch 30/100
# 3765/3765 [==============================] - 36s 9ms/step - loss: 1.1221e-04 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 0.9954
# Epoch 31/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 5.3694e-05 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 0.9954
# Epoch 32/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 8.8124e-05 - accuracy: 1.0000 - val_loss: 0.0322 - val_accuracy: 0.9953
# Epoch 33/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.2182e-04 - accuracy: 0.9999 - val_loss: 0.0270 - val_accuracy: 0.9959
# Epoch 34/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 1.7894e-05 - accuracy: 1.0000 - val_loss: 0.0296 - val_accuracy: 0.9959
# Epoch 35/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 1.4801e-04 - accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 0.9931
# Epoch 36/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 1.5203e-04 - accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 0.9956
# Epoch 37/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 1.1484e-04 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 0.9954
# Epoch 38/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 2.1919e-04 - accuracy: 0.9999 - val_loss: 0.0292 - val_accuracy: 0.9957
# Epoch 39/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 1.2946e-04 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9957
# Epoch 40/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.5146e-05 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9948
# Epoch 41/100
# 3765/3765 [==============================] - 36s 9ms/step - loss: 1.8219e-05 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9959
# Epoch 42/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.4335e-04 - accuracy: 1.0000 - val_loss: 0.0308 - val_accuracy: 0.9957
# Epoch 43/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 9.6675e-05 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 0.9960
# Epoch 44/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 1.4626e-04 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9958
# Epoch 45/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 8.1919e-05 - accuracy: 1.0000 - val_loss: 0.0319 - val_accuracy: 0.9959
# Epoch 46/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 1.7029e-05 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9960
# Epoch 47/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 3.8262e-05 - accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9964
# Epoch 48/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.4792e-04 - accuracy: 0.9999 - val_loss: 0.0276 - val_accuracy: 0.9961
# Epoch 49/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 7.0452e-05 - accuracy: 1.0000 - val_loss: 0.0325 - val_accuracy: 0.9962
# Epoch 50/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 1.0527e-04 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 0.9959
# Epoch 51/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 3.2808e-04 - accuracy: 0.9999 - val_loss: 0.0296 - val_accuracy: 0.9958
# Epoch 52/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 1.5654e-05 - accuracy: 1.0000 - val_loss: 0.0305 - val_accuracy: 0.9962
# Epoch 53/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 2.2945e-05 - accuracy: 1.0000 - val_loss: 0.0355 - val_accuracy: 0.9956
# Epoch 54/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 1.2762e-04 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9957
# Epoch 55/100
# 3765/3765 [==============================] - 33s 9ms/step - loss: 1.6006e-05 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9956
# Epoch 56/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 1.5142e-04 - accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 0.9960
# Epoch 57/100
# 3765/3765 [==============================] - 33s 9ms/step - loss: 2.8817e-05 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9959
# Epoch 58/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 8.8241e-05 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9958
# Epoch 59/100
# 3765/3765 [==============================] - 33s 9ms/step - loss: 6.0230e-05 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9960
# Epoch 60/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 1.9708e-05 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9960
# Epoch 61/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 1.5670e-05 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9960
# Epoch 62/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 1.7667e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9961
# Epoch 63/100
# 3765/3765 [==============================] - 33s 9ms/step - loss: 1.7221e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9960
# Epoch 64/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 1.3289e-04 - accuracy: 1.0000 - val_loss: 0.0463 - val_accuracy: 0.9956
# Epoch 65/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 1.5513e-05 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 0.9956
# Epoch 66/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.7197e-04 - accuracy: 0.9999 - val_loss: 0.0381 - val_accuracy: 0.9953
# Epoch 67/100
# 3765/3765 [==============================] - 36s 10ms/step - loss: 1.5676e-04 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9946
# Epoch 68/100
# 3765/3765 [==============================] - 36s 10ms/step - loss: 2.7696e-05 - accuracy: 1.0000 - val_loss: 0.0370 - val_accuracy: 0.9956
# Epoch 69/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.0773e-04 - accuracy: 0.9999 - val_loss: 0.0346 - val_accuracy: 0.9954
# Epoch 70/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 6.4396e-05 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9955
# Epoch 71/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.9250e-05 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9960
# Epoch 72/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 1.4887e-05 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9954
# Epoch 73/100
# 3765/3765 [==============================] - 38s 10ms/step - loss: 1.3718e-04 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 0.9959
# Epoch 74/100
# 3765/3765 [==============================] - 38s 10ms/step - loss: 1.0114e-04 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9962
# Epoch 75/100
# 3765/3765 [==============================] - 36s 10ms/step - loss: 1.5314e-05 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 0.9963
# Epoch 76/100
# 3765/3765 [==============================] - 36s 10ms/step - loss: 1.7255e-05 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9963
# Epoch 77/100
# 3765/3765 [==============================] - 36s 10ms/step - loss: 2.7870e-04 - accuracy: 0.9999 - val_loss: 0.0284 - val_accuracy: 0.9960
# Epoch 78/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 1.5869e-05 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9958
# Epoch 79/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 8.8755e-05 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 0.9957
# Epoch 80/100
# 3765/3765 [==============================] - 33s 9ms/step - loss: 2.4550e-05 - accuracy: 1.0000 - val_loss: 0.0370 - val_accuracy: 0.9959
# Epoch 81/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 1.5659e-05 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9958
# Epoch 82/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 8.8433e-05 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9958
# Epoch 83/100
# 3765/3765 [==============================] - 36s 10ms/step - loss: 1.0361e-04 - accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9956
# Epoch 84/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.1989e-04 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9958
# Epoch 85/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 9.8397e-05 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9958
# Epoch 86/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.3973e-05 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9960
# Epoch 87/100
# 3765/3765 [==============================] - 33s 9ms/step - loss: 1.0236e-04 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9960
# Epoch 88/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 1.9585e-05 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9959
# Epoch 89/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 1.0068e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9958
# Epoch 90/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.6287e-05 - accuracy: 1.0000 - val_loss: 0.0354 - val_accuracy: 0.9963
# Epoch 91/100
# 3765/3765 [==============================] - 33s 9ms/step - loss: 1.8168e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9961
# Epoch 92/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.4830e-04 - accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9957
# Epoch 93/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.2956e-04 - accuracy: 0.9999 - val_loss: 0.0438 - val_accuracy: 0.9940
# Epoch 94/100
# 3765/3765 [==============================] - 37s 10ms/step - loss: 1.6418e-04 - accuracy: 1.0000 - val_loss: 0.0325 - val_accuracy: 0.9955
# Epoch 95/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 1.3605e-05 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9961
# Epoch 96/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 2.6557e-04 - accuracy: 0.9999 - val_loss: 0.0395 - val_accuracy: 0.9952
# Epoch 97/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 1.1768e-04 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 0.9956
# Epoch 98/100
# 3765/3765 [==============================] - 34s 9ms/step - loss: 3.0159e-05 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9955
# Epoch 99/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 4.1811e-05 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9954
# Epoch 100/100
# 3765/3765 [==============================] - 35s 9ms/step - loss: 2.6575e-05 - accuracy: 1.0000 - val_loss: 0.0455 - val_accuracy: 0.9953

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model.evaluate(text_dataset.x_test, text_dataset.y_test)
# Out:
# 1255/1255 [==============================] - 5s 4ms/step - loss: 0.0413 - accuracy: 0.9957
# [0.041339315474033356, 0.9957413077354431]

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Embedding, Dropout
from tensorflow.keras.layers import MultiHeadAttention, LayerNormalization
from tensorflow.keras.models import Model

# %%
def create_model_1(self, embedding_dim=50, num_filters=64, filter_size=3, dropout_rate=0.5, lstm_units=64):
          
    embedding_dim = 50
    num_filters = 32
    filter_size = 3
    dropout_rate = 0.2
    lstm_units = 64
    num_heads = 6
    dff = 512
    num_layers = 2


    inputs = Input(shape=(self.max_sequence_length,), name='input_layer')
    embedding_layer = Embedding(input_dim=self.tokenizer.num_words, output_dim=embedding_dim, name='embedding_layer')(inputs)

    encoder_output = embedding_layer
    for i in range(num_layers):
        attention_output = MultiHeadAttention(num_heads=num_heads, key_dim=embedding_dim)(encoder_output, encoder_output)
        attention_output = Dropout(dropout_rate)(attention_output)
        attention_output = LayerNormalization(epsilon=1e-6)(encoder_output + attention_output)
        
        feedforward_output = Dense(dff, activation='relu')(attention_output)
        feedforward_output = Dense(embedding_dim)(feedforward_output)
        feedforward_output = Dropout(dropout_rate)(feedforward_output)
        feedforward_output = LayerNormalization(epsilon=1e-6)(attention_output + feedforward_output)
        encoder_output = feedforward_output
    output_layer = Dense(1, activation='sigmoid', name='output_layer')(tf.keras.layers.Reshape((-1,))(encoder_output))
    model = Model(inputs=inputs, outputs=output_layer)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
text_dataset.create_model = create_model_1

# %%
model = text_dataset.create_model(text_dataset)

# %%
history = model.fit(text_dataset.x_train, text_dataset.y_train, epochs=100, batch_size=32, validation_data=(text_dataset.x_val, text_dataset.y_val))
# Out:
# Epoch 1/100
# 3765/3765 [==============================] - 100s 25ms/step - loss: 0.1561 - accuracy: 0.9055 - val_loss: 0.0163 - val_accuracy: 0.9942
# Epoch 2/100
# 3765/3765 [==============================] - 66s 18ms/step - loss: 0.0117 - accuracy: 0.9965 - val_loss: 0.0156 - val_accuracy: 0.9946
# Epoch 3/100
# 3765/3765 [==============================] - 62s 17ms/step - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.0254 - val_accuracy: 0.9948
# Epoch 4/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.0221 - val_accuracy: 0.9950
# Epoch 5/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0270 - val_accuracy: 0.9955
# Epoch 6/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0317 - val_accuracy: 0.9955
# Epoch 7/100
# 3765/3765 [==============================] - 74s 20ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0241 - val_accuracy: 0.9952
# Epoch 8/100
# 3765/3765 [==============================] - 61s 16ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0245 - val_accuracy: 0.9953
# Epoch 9/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0357 - val_accuracy: 0.9953
# Epoch 10/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0282 - val_accuracy: 0.9955
# Epoch 11/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0334 - val_accuracy: 0.9945
# Epoch 12/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.0243 - val_accuracy: 0.9955
# Epoch 13/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0316 - val_accuracy: 0.9951
# Epoch 14/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0276 - val_accuracy: 0.9954
# Epoch 15/100
# 3765/3765 [==============================] - 66s 17ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0327 - val_accuracy: 0.9956
# Epoch 16/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0325 - val_accuracy: 0.9955
# Epoch 17/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0304 - val_accuracy: 0.9962
# Epoch 18/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 8.6443e-04 - accuracy: 0.9998 - val_loss: 0.0377 - val_accuracy: 0.9952
# Epoch 19/100
# 3765/3765 [==============================] - 63s 17ms/step - loss: 5.7605e-04 - accuracy: 0.9999 - val_loss: 0.0437 - val_accuracy: 0.9961
# Epoch 20/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0351 - val_accuracy: 0.9960
# Epoch 21/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0334 - val_accuracy: 0.9957
# Epoch 22/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0320 - val_accuracy: 0.9959
# Epoch 23/100
# 3765/3765 [==============================] - 62s 17ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0278 - val_accuracy: 0.9958
# Epoch 24/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0249 - val_accuracy: 0.9957
# Epoch 25/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0210 - val_accuracy: 0.9957
# Epoch 26/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0153 - val_accuracy: 0.9960
# Epoch 27/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0217 - val_accuracy: 0.9966
# Epoch 28/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 6.6601e-04 - accuracy: 0.9999 - val_loss: 0.0389 - val_accuracy: 0.9943
# Epoch 29/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 9.0155e-04 - accuracy: 0.9998 - val_loss: 0.0287 - val_accuracy: 0.9965
# Epoch 30/100
# 3765/3765 [==============================] - 61s 16ms/step - loss: 8.8885e-04 - accuracy: 0.9997 - val_loss: 0.0274 - val_accuracy: 0.9960
# Epoch 31/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0360 - val_accuracy: 0.9955
# Epoch 32/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0254 - val_accuracy: 0.9961
# Epoch 33/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0284 - val_accuracy: 0.9961
# Epoch 34/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0348 - val_accuracy: 0.9948
# Epoch 35/100
# 3765/3765 [==============================] - 61s 16ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0291 - val_accuracy: 0.9964
# Epoch 36/100
# 3765/3765 [==============================] - 63s 17ms/step - loss: 9.7365e-04 - accuracy: 0.9998 - val_loss: 0.0289 - val_accuracy: 0.9955
# Epoch 37/100
# 3765/3765 [==============================] - 62s 17ms/step - loss: 7.9546e-04 - accuracy: 0.9998 - val_loss: 0.0293 - val_accuracy: 0.9965
# Epoch 38/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 9.6897e-04 - accuracy: 0.9997 - val_loss: 0.0283 - val_accuracy: 0.9956
# Epoch 39/100
# 3765/3765 [==============================] - 62s 16ms/step - loss: 9.1028e-04 - accuracy: 0.9998 - val_loss: 0.0238 - val_accuracy: 0.9962
# Epoch 40/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 7.3445e-04 - accuracy: 0.9999 - val_loss: 0.0365 - val_accuracy: 0.9962
# Epoch 41/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0222 - val_accuracy: 0.9966
# Epoch 42/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 6.4235e-04 - accuracy: 0.9998 - val_loss: 0.0243 - val_accuracy: 0.9969
# Epoch 43/100
# 3765/3765 [==============================] - 62s 16ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0204 - val_accuracy: 0.9962
# Epoch 44/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0261 - val_accuracy: 0.9970
# Epoch 45/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0328 - val_accuracy: 0.9961
# Epoch 46/100
# 3765/3765 [==============================] - 62s 16ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0330 - val_accuracy: 0.9964
# Epoch 47/100
# 3765/3765 [==============================] - 61s 16ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0311 - val_accuracy: 0.9950
# Epoch 48/100
# 3765/3765 [==============================] - 61s 16ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0239 - val_accuracy: 0.9961
# Epoch 49/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0332 - val_accuracy: 0.9957
# Epoch 50/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0291 - val_accuracy: 0.9958
# Epoch 51/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0229 - val_accuracy: 0.9957
# Epoch 52/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0236 - val_accuracy: 0.9939
# Epoch 53/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0229 - val_accuracy: 0.9961
# Epoch 54/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0265 - val_accuracy: 0.9958
# Epoch 55/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0255 - val_accuracy: 0.9950
# Epoch 56/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0251 - val_accuracy: 0.9951
# Epoch 57/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0306 - val_accuracy: 0.9952
# Epoch 58/100
# 3765/3765 [==============================] - 63s 17ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.0181 - val_accuracy: 0.9962
# Epoch 59/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0219 - val_accuracy: 0.9959
# Epoch 60/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0255 - val_accuracy: 0.9963
# Epoch 61/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0286 - val_accuracy: 0.9968
# Epoch 62/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0245 - val_accuracy: 0.9967
# Epoch 63/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 7.4734e-04 - accuracy: 0.9998 - val_loss: 0.0288 - val_accuracy: 0.9964
# Epoch 64/100
# 3765/3765 [==============================] - 62s 16ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0301 - val_accuracy: 0.9962
# Epoch 65/100
# 3765/3765 [==============================] - 63s 17ms/step - loss: 4.5767e-04 - accuracy: 0.9999 - val_loss: 0.0287 - val_accuracy: 0.9967
# Epoch 66/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0297 - val_accuracy: 0.9963
# Epoch 67/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0308 - val_accuracy: 0.9959
# Epoch 68/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0212 - val_accuracy: 0.9961
# Epoch 69/100
# 3765/3765 [==============================] - 61s 16ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0237 - val_accuracy: 0.9965
# Epoch 70/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 8.2018e-04 - accuracy: 0.9998 - val_loss: 0.0321 - val_accuracy: 0.9962
# Epoch 71/100
# 3765/3765 [==============================] - 60s 16ms/step - loss: 6.9988e-04 - accuracy: 0.9998 - val_loss: 0.0355 - val_accuracy: 0.9960
# Epoch 72/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0386 - val_accuracy: 0.9952
# Epoch 73/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0289 - val_accuracy: 0.9956
# Epoch 74/100
# 3765/3765 [==============================] - 61s 16ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0271 - val_accuracy: 0.9962
# Epoch 75/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 9.5395e-04 - accuracy: 0.9998 - val_loss: 0.0276 - val_accuracy: 0.9959
# Epoch 76/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 9.9290e-04 - accuracy: 0.9998 - val_loss: 0.0313 - val_accuracy: 0.9960
# Epoch 77/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0296 - val_accuracy: 0.9958
# Epoch 78/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0331 - val_accuracy: 0.9960
# Epoch 79/100
# 3765/3765 [==============================] - 61s 16ms/step - loss: 6.7785e-04 - accuracy: 0.9998 - val_loss: 0.0568 - val_accuracy: 0.9924
# Epoch 80/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 6.9438e-04 - accuracy: 0.9998 - val_loss: 0.0347 - val_accuracy: 0.9961
# Epoch 81/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 4.6606e-04 - accuracy: 0.9999 - val_loss: 0.0315 - val_accuracy: 0.9961
# Epoch 82/100
# 3765/3765 [==============================] - 62s 16ms/step - loss: 6.2982e-04 - accuracy: 0.9999 - val_loss: 0.0300 - val_accuracy: 0.9961
# Epoch 83/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 2.0165e-04 - accuracy: 0.9999 - val_loss: 0.0366 - val_accuracy: 0.9958
# Epoch 84/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 8.4156e-05 - accuracy: 1.0000 - val_loss: 0.0491 - val_accuracy: 0.9961
# Epoch 85/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 4.8277e-04 - accuracy: 0.9999 - val_loss: 0.0465 - val_accuracy: 0.9959
# Epoch 86/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 2.8428e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9958
# Epoch 87/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 3.4095e-04 - accuracy: 0.9999 - val_loss: 0.0429 - val_accuracy: 0.9965
# Epoch 88/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 5.9466e-04 - accuracy: 0.9999 - val_loss: 0.0416 - val_accuracy: 0.9963
# Epoch 89/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 5.8172e-04 - accuracy: 0.9999 - val_loss: 0.0527 - val_accuracy: 0.9955
# Epoch 90/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 4.0155e-04 - accuracy: 0.9999 - val_loss: 0.0359 - val_accuracy: 0.9962
# Epoch 91/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 7.6121e-04 - accuracy: 0.9998 - val_loss: 0.0421 - val_accuracy: 0.9959
# Epoch 92/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 6.4117e-04 - accuracy: 0.9999 - val_loss: 0.0377 - val_accuracy: 0.9951
# Epoch 93/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 3.8634e-04 - accuracy: 0.9999 - val_loss: 0.0381 - val_accuracy: 0.9963
# Epoch 94/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 4.9202e-04 - accuracy: 0.9999 - val_loss: 0.0392 - val_accuracy: 0.9958
# Epoch 95/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 7.7987e-04 - accuracy: 0.9998 - val_loss: 0.0376 - val_accuracy: 0.9958
# Epoch 96/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 5.6453e-04 - accuracy: 0.9999 - val_loss: 0.0427 - val_accuracy: 0.9962
# Epoch 97/100
# 3765/3765 [==============================] - 65s 17ms/step - loss: 4.4311e-04 - accuracy: 0.9999 - val_loss: 0.0370 - val_accuracy: 0.9962
# Epoch 98/100
# 3765/3765 [==============================] - 61s 16ms/step - loss: 2.4708e-04 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9961
# Epoch 99/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 4.3094e-04 - accuracy: 0.9999 - val_loss: 0.0472 - val_accuracy: 0.9965
# Epoch 100/100
# 3765/3765 [==============================] - 64s 17ms/step - loss: 2.2737e-04 - accuracy: 0.9999 - val_loss: 0.0500 - val_accuracy: 0.9957

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model.evaluate(text_dataset.x_test, text_dataset.y_test)
# Out:
# 1255/1255 [==============================] - 8s 7ms/step - loss: 0.0469 - accuracy: 0.9956
# [0.04690100997686386, 0.9956416487693787]
